# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.tree import DecisionTreeClassifier

# Load dataset
x, y = load_iris(return_X_y=True)

# Train-test split
x_train, x_test, y_train, y_test = train_test_split(
    x,
    y,
    test_size=0.2,
    random_state=42,
    stratify=y
)

# Try different max_depth values
for depth in [1, 2, 3, 4, 5, 10]:

    model = DecisionTreeClassifier(
        max_depth=depth,
        random_state=42
    )

    scores = cross_val_score(
        model,
        x_train,
        y_train,
        cv=5,
        scoring="accuracy"
    )

    print(
        f"max_depth={depth:<2} | "
        f"Mean CV Accuracy={scores.mean():.4f}"
    )
# Out:
# max_depth=1  | Mean CV Accuracy=0.6667
# max_depth=2  | Mean CV Accuracy=0.9250
# max_depth=3  | Mean CV Accuracy=0.9333
# max_depth=4  | Mean CV Accuracy=0.9417
# max_depth=5  | Mean CV Accuracy=0.9417
# max_depth=10 | Mean CV Accuracy=0.9417

# %%
# GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier(random_state=42)

param_grid = {
    "max_depth": [1, 2, 3, 4, 5, 10],
    "min_samples_split": [2, 5, 10]
}

# %%
grid = GridSearchCV(
    estimator=model,
    param_grid=param_grid,
    cv=5,
    scoring="accuracy"
)

# %%
grid.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=42),
#              param_grid={'max_depth': [1, 2, 3, 4, 5, 10],
#                          'min_samples_split': [2, 5, 10]},
#              scoring='accuracy')

# %%
print("Best Parameters:")
print(grid.best_params_)
# Out:
# Best Parameters:
# {'max_depth': 4, 'min_samples_split': 2}

# %%
print("Best CV Score:")
print(grid.best_score_)
# Out:
# Best CV Score:
# 0.9416666666666668

# %%
best_model = grid.best_estimator_

print(best_model)
# Out:
# DecisionTreeClassifier(max_depth=4, random_state=42)

# %%
test_accuracy = best_model.score(
    x_test,
    y_test
)

print("Test Accuracy:", test_accuracy)
# Out:
# Test Accuracy: 0.9333333333333333

# %%
results = grid.cv_results_

print(results["params"])
print(results["mean_test_score"])
# Out:
# [{'max_depth': 1, 'min_samples_split': 2}, {'max_depth': 1, 'min_samples_split': 5}, {'max_depth': 1, 'min_samples_split': 10}, {'max_depth': 2, 'min_samples_split': 2}, {'max_depth': 2, 'min_samples_split': 5}, {'max_depth': 2, 'min_samples_split': 10}, {'max_depth': 3, 'min_samples_split': 2}, {'max_depth': 3, 'min_samples_split': 5}, {'max_depth': 3, 'min_samples_split': 10}, {'max_depth': 4, 'min_samples_split': 2}, {'max_depth': 4, 'min_samples_split': 5}, {'max_depth': 4, 'min_samples_split': 10}, {'max_depth': 5, 'min_samples_split': 2}, {'max_depth': 5, 'min_samples_split': 5}, {'max_depth': 5, 'min_samples_split': 10}, {'max_depth': 10, 'min_samples_split': 2}, {'max_depth': 10, 'min_samples_split': 5}, {'max_depth': 10, 'min_samples_split': 10}]
# [0.66666667 0.66666667 0.66666667 0.925      0.925      0.925
#  0.93333333 0.93333333 0.93333333 0.94166667 0.93333333 0.93333333
#  0.94166667 0.93333333 0.93333333 0.94166667 0.93333333 0.93333333]

# %%
# RandomizedSearchCV

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier(random_state=42)

param_grid = {
    "max_depth": [1, 2, 3, 4, 5, 10],
    "min_samples_split": [2, 5, 10],
    "criterion": ["gini", "entropy"]
}

# %%
random_search = RandomizedSearchCV(
    estimator= model,
    param_distributions= param_grid,
    n_iter= 10,
    cv= 5,
    scoring= 'accuracy',
    random_state=42
)

# %%
random_search.fit(x_train, y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=42),
#                    param_distributions={'criterion': ['gini', 'entropy'],
#                                         'max_depth': [1, 2, 3, 4, 5, 10],
#                                         'min_samples_split': [2, 5, 10]},
#                    random_state=42, scoring='accuracy')

# %%
print("Best Parameters:")
print(random_search.best_params_)
# Out:
# Best Parameters:
# {'min_samples_split': 2, 'max_depth': 5, 'criterion': 'gini'}

# %%
print("Best CV Score:")
print(random_search.best_score_)
# Out:
# Best CV Score:
# 0.9416666666666668

# %%
best_random_model = random_search.best_estimator_

print(best_random_model)
# Out:
# DecisionTreeClassifier(max_depth=5, random_state=42)

# %%
test_accuracy = best_random_model.score(
    x_test,
    y_test
)
print('Test Accuracy: ',test_accuracy)
# Out:
# Test Accuracy:  0.9333333333333333

# %% [markdown]
# # 03. Hyperparameter Tuning
#
# ## 1. Parameters vs Hyperparameters
#
# ### Parameters
#
# Parameters are values that the **model learns from the training data**.
#
# Example in Linear Regression:
#
# $$
# y = w_1x_1 + w_2x_2 + b
# $$
#
# ```text
# w₁, w₂ → Weights
# b      → Bias
# ```
#
# These are learned during training.
#
# ```text
# Training Data
#      ↓
# model.fit()
#      ↓
# Parameters learned
# ```
#
# ### Hyperparameters
#
# Hyperparameters are settings that **we choose before training**.
#
# Example:
#
# ```python
# RandomForestClassifier(
#     n_estimators=100,
#     max_depth=5
# )
# ```
#
# ```text
# n_estimators
# max_depth
# ```
#
# are hyperparameters.
#
# ### Main Difference
#
# ```text
# Parameters
# → Learned by the model
#
# Hyperparameters
# → Chosen by us
# ```
#
# ---
#
# # 2. Why Hyperparameter Tuning?
#
# Different hyperparameter values can produce different model performance.
#
# Example:
#
# ```text
# max_depth = 1
# → Model too simple
# → Underfitting
#
# max_depth = 5
# → More suitable complexity
#
# max_depth = 30
# → Model may become too complex
# → Overfitting
# ```
#
# Therefore, we try different hyperparameter values and select a configuration that performs well.
#
# > **Hyperparameter Tuning is the process of searching for suitable hyperparameter values for a machine learning model.**
#
# ---
#
# # 3. Hyperparameter Tuning + Cross-Validation
#
# Cross-Validation helps us evaluate different hyperparameter configurations.
#
# ```text
# Hyperparameter values
#         ↓
# Cross-Validation
#         ↓
# CV Scores
#         ↓
# Compare scores
#         ↓
# Best Hyperparameters
# ```
#
# Example:
#
# ```text
# max_depth = 2
# → CV Accuracy = 0.925
#
# max_depth = 3
# → CV Accuracy = 0.933
#
# max_depth = 4
# → CV Accuracy = 0.942
# ```
#
# So `max_depth = 4` performs best among the tested values.
#
# ---
#
# # 4. Manual Hyperparameter Search
#
# We can manually test different values.
#
# ```python
# for depth in [1, 2, 3, 4, 5, 10]:
#
#     model = DecisionTreeClassifier(
#         max_depth=depth,
#         random_state=42
#     )
#
#     scores = cross_val_score(
#         model,
#         x_train,
#         y_train,
#         cv=5,
#         scoring="accuracy"
#     )
#
#     print(
#         f"max_depth={depth} | "
#         f"Mean CV Accuracy={scores.mean():.4f}"
#     )
# ```
#
# The process is:
#
# ```text
# Different max_depth values
#           ↓
# 5-Fold Cross-Validation
#           ↓
# Mean CV Accuracy
#           ↓
# Compare results
#           ↓
# Choose the best value
# ```
#
# Manual searching becomes inconvenient when we have many hyperparameters.
#
# ---
#
# # 5. GridSearchCV
#
# `GridSearchCV` automatically searches through the hyperparameter combinations we provide.
#
# ```python
# from sklearn.model_selection import GridSearchCV
# from sklearn.tree import DecisionTreeClassifier
#
# model = DecisionTreeClassifier(random_state=42)
#
# param_grid = {
#     "max_depth": [1, 2, 3, 4, 5, 10],
#     "min_samples_split": [2, 5, 10]
# }
# ```
#
# Number of combinations:
#
# $$
# 6 \times 3 = 18
# $$
#
# So GridSearchCV tests **18 combinations**.
#
# ---
#
# ## Creating GridSearchCV
#
# ```python
# grid = GridSearchCV(
#     estimator=model,
#     param_grid=param_grid,
#     cv=5,
#     scoring="accuracy"
# )
# ```
#
# ### Important arguments
#
# ```text
# estimator
# → Model being tuned
#
# param_grid
# → Hyperparameter values to test
#
# cv=5
# → 5-Fold Cross-Validation
#
# scoring="accuracy"
# → Metric used to compare models
# ```
#
# ---
#
# # 6. Running Grid Search
#
# ```python
# grid.fit(x_train, y_train)
# ```
#
# Internally:
#
# ```text
# 18 Hyperparameter Combinations
#             ↓
#        5-Fold CV
#             ↓
#       Calculate Scores
#             ↓
#        Compare Scores
#             ↓
#     Select Best Combination
# ```
#
# In our experiment:
#
# ```text
# Best Parameters:
# max_depth = 4
# min_samples_split = 2
# ```
#
# ```text
# Best CV Score:
# 0.9417
# ```
#
# ---
#
# # 7. `best_params_`
#
# ```python
# grid.best_params_
# ```
#
# Returns the hyperparameter combination that achieved the best CV score.
#
# Example:
#
# ```python
# {
#     "max_depth": 4,
#     "min_samples_split": 2
# }
# ```
#
# Meaning:
#
# ```text
# max_depth = 4
# min_samples_split = 2
# ```
#
# gave the best CV performance among the combinations we tested.
#
# ---
#
# # 8. `best_score_`
#
# ```python
# grid.best_score_
# ```
#
# Returns the **best mean Cross-Validation score**.
#
# Our result:
#
# ```text
# 0.9416666666666668
# ```
#
# Approximately:
#
# ```text
# 94.17%
# ```
#
# ---
#
# # 9. `best_estimator_`
#
# ```python
# best_model = grid.best_estimator_
# ```
#
# Returns the model configured with the best hyperparameters.
#
# Example:
#
# ```text
# DecisionTreeClassifier(
#     max_depth=4,
#     random_state=42
# )
# ```
#
# `min_samples_split=2` is not displayed because `2` is its default value.
#
# ---
#
# # 10. Final Test Evaluation
#
# After selecting the best model using the training data and Cross-Validation:
#
# ```python
# test_accuracy = best_model.score(
#     x_test,
#     y_test
# )
#
# print("Test Accuracy:", test_accuracy)
# ```
#
# Our result:
#
# ```text
# Test Accuracy = 93.33%
# ```
#
# So:
#
# ```text
# Best CV Accuracy
# → 94.17%
#
# Final Test Accuracy
# → 93.33%
# ```
#
# The test set was kept separate during hyperparameter tuning.
#
# ---
#
# # 11. GridSearchCV Workflow
#
# ```text
# Dataset
#    ↓
# Train / Test Split
#    ↓
# x_train, y_train
#    ↓
# Define Hyperparameters
#    ↓
# GridSearchCV
#    ↓
# Cross-Validation
#    ↓
# Compare Combinations
#    ↓
# Best Hyperparameters
#    ↓
# Best Model
#    ↓
# Final Test Set
#    ↓
# Test Performance
# ```
#
# ---
#
# # 12. RandomizedSearchCV
#
# GridSearchCV tests **every combination** in the search space.
#
# When the search space becomes very large, this can become expensive.
#
# `RandomizedSearchCV` tests only a specified number of combinations.
#
# ```python
# from sklearn.model_selection import RandomizedSearchCV
# ```
#
# Example:
#
# ```python
# param_grid = {
#     "max_depth": [1, 2, 3, 4, 5, 10],
#     "min_samples_split": [2, 5, 10],
#     "criterion": ["gini", "entropy"]
# }
# ```
#
# Number of possible combinations:
#
# $$
# 6 \times 3 \times 2 = 36
# $$
#
# Instead of testing all 36:
#
# ```python
# random_search = RandomizedSearchCV(
#     estimator=model,
#     param_distributions=param_grid,
#     n_iter=10,
#     cv=5,
#     scoring="accuracy",
#     random_state=42
# )
# ```
#
# Here:
#
# ```text
# n_iter=10
# → Test 10 combinations
# ```
#
# ---
#
# # 13. Grid Search vs Random Search
#
# | GridSearchCV                   | RandomizedSearchCV            |
# | ------------------------------ | ----------------------------- |
# | Tests every combination        | Tests selected combinations   |
# | More exhaustive                | Less exhaustive               |
# | Can be expensive               | Usually faster                |
# | Good for smaller search spaces | Good for larger search spaces |
#
# ```text
# Grid Search
# → "Try everything."
#
# Random Search
# → "Try some combinations efficiently."
# ```
#
# ---
#
# # 14. Important Difference
#
# Grid Search:
#
# ```text
# Possible combinations
#         ↓
# ALL combinations
#         ↓
# Cross-Validation
#         ↓
# Best combination
# ```
#
# Random Search:
#
# ```text
# Possible combinations
#         ↓
# Selected combinations
#         ↓
# Cross-Validation
#         ↓
# Best combination among tested combinations
# ```
#
# Random Search may not find the absolute best combination because it doesn't test everything.
#
# ---
#
# # 15. Avoiding Data Leakage
#
# The test set should remain untouched during hyperparameter tuning.
#
# Correct workflow:
#
# ```text
# Full Dataset
#      ↓
# Train / Test Split
#      ↓
# Training Data
#      ↓
# Hyperparameter Tuning
#      ↓
# Cross-Validation
#      ↓
# Best Model
#      ↓
# Test Data
#      ↓
# Final Evaluation
# ```
#
# Do **not** repeatedly use the test set to choose hyperparameters.
#
# ---
#
# # ⭐ Key Points
#
# ```text
# Parameters
# → Learned by the model
# ```
#
# ```text
# Hyperparameters
# → Chosen before training
# ```
#
# ```text
# Hyperparameter Tuning
# → Search for good hyperparameter values
# ```
#
# ```text
# GridSearchCV
# → Tests every specified combination
# ```
#
# ```text
# RandomizedSearchCV
# → Tests a limited number of combinations
# ```
#
# ```text
# best_params_
# → Best hyperparameter values
# ```
#
# ```text
# best_score_
# → Best CV score
# ```
#
# ```text
# best_estimator_
# → Best configured model
# ```
#
# ```text
# Test Set
# → Used only for final evaluation
# ```
#
# ### One-line summary
#
# > **Hyperparameter tuning searches for suitable model settings, while Cross-Validation evaluates those settings across multiple data splits.**
